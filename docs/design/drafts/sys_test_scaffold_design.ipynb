# %%
# look at scafolding notebooks of spannerlib

Class SysTestScafold:
    def __init__(self):
        self.pyg = None
        self.relnn_str = None  # or exported relnn_module
        self.params_mapping = None
    
    def shapes_match(self):
        # check if self.pyg.shape == self.relnn_str.shape
        # if not -> assert + meaningful message with shapes
        pass
    
    def copy_and_init_weights():
        pass
    
    def first_forward_pass():
        # check output is the same
        pass
    
    def comparable_loss():
        # check if loss is the same
        pass
    
    def the_same_predictions():
        pass
    
    def comparable_weights_after_training():
        pass
    
    def run_time_comparison():
        pass

# %%
# add these:

# %load_ext autoreload
# %autoreload 2
# ---
# import nbdev; nbdev.nbdev_export()
